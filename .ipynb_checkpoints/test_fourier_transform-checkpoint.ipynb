# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
def show(img):
    if img.ndim == 2:
        plt.imshow(img, cmap='gray')
    else:
        img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
        plt.imshow(img)
    plt.show()

# %% [markdown]
# ## 15. 傅里叶变换

# %%
I  = cv.imread('pic/cat500x480.jpg', 0)
show(I)

# %%
f = np.fft.fft2(I)

fshift = np.fft.fftshift(f)

v = np.log(np.abs(fshift))

# %%
plt.imshow(v, cmap='gray')
plt.show()

# %%
I2 = np.fft.ifft2(f)

I22 = np.abs(I2)

show(I22)

# %%
(I22.astype(np.uint8) != I).sum()
# Out:
# 94254

# %%
def dft2_1(I, u, v):
    N, M = I.shape
    Re = 0.0
    Im = 0.0
    for x in range(M):
        for y in range(N):
            power = -2 * np.pi * (u*x/M + v*y/N)
            Re += I[y,x] * np.cos(power)
            Im += I[y,x] * np.sin(power)
    return Re + Im*1j

# %%
def dft2_2(I, u, v):
    N, M = I.shape
    
    x = np.arange(0, M, 1)
    y = np.arange(0, N, 1).reshape((N, 1))

    power = -2 * np.pi * (u*x/M + v*y/N)
    
    Re = (I * np.cos(power)).sum()
    Im = (I * np.sin(power)).sum()
    return Re + Im*1j

# %%
I = np.ones((50,100))
I[:, :50] = 0

# %%
res = np.zeros((50, 100), dtype=np.complex128)
for u in range(50):
    for v in range(100):
        res[u,v] = dft2_2(I, v, u)

show(np.log(np.abs(res) + 1))

plt.plot(np.log(np.abs(res) + 1)[0, :], 'ro')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-346-6c29c7ef1b43> in <module>
#       2 for u in range(50):
#       3     for v in range(100):
# ----> 4         res[u,v] = dft2_2(I, v, u)
#       5
#       6 show(np.log(np.abs(res) + 1))
#
# <ipython-input-228-1156a900a7c2> in dft2_2(I, u, v)
#       7     power = -2 * np.pi * (u*x/M + v*y/N)
#       8
# ----> 9     Re = (I * np.cos(power)).sum()
#      10     Im = (I * np.sin(power)).sum()
#      11     return Re + Im*1j
#
# KeyboardInterrupt:

# %%
res2 = res.copy()
res2[:, :50] = 0 + 0*1j

show(np.log(np.abs(res2)+1))

# %%
I2 = np.fft.ifft2(res2)

show(np.abs(I2))

# %%
show(I)

# %%
res2 = res.copy()
res2[:, 40:] = 0 + 0*1j

I3 = np.fft.ifft2(res2)

show(np.abs(I3))

# %%
res2 = res.copy()
res2[:, 1] = 0 + 0*1j

I3 = np.fft.ifft2(res2)

show(np.abs(I3))

# %%
I = np.ones((50,100))
I[:, :30] = 0
I[:, 70:] = 0

res = np.zeros((50, 100), dtype=np.complex128)
for u in range(50):
    for v in range(100):
        res[u,v] = dft2_2(I, v, u)

show(np.log(np.abs(res) + 1))

plt.plot(np.log(np.abs(res) + 1)[0, :], 'ro')
plt.show()

# %%
I = np.ones((50,100))
I[:, :30] = 0
I[:, 40:50] = 0
I[:, 70:] = 0

res = np.zeros((50, 100), dtype=np.complex128)
for u in range(50):
    for v in range(100):
        res[u,v] = dft2_2(I, v, u)

show(np.log(np.abs(res) + 1))

plt.plot(np.log(np.abs(res) + 1)[0, :], 'ro')
plt.show()

# %%
I = np.ones((50,100))
I[:, ::10] = 0
I[:, 1::10] = 0


res = np.zeros((50, 100), dtype=np.complex128)
for u in range(50):
    for v in range(100):
        res[u,v] = dft2_2(I, v, u)

show(np.log(np.abs(res) + 1))

plt.plot(np.log(np.abs(res) + 1)[0, :], 'ro')
plt.show()

# %%
show(I)

# %%
res[0, :20] = 0 + 0*1j
iI = np.fft.ifft2(res)

show(np.abs(iI))

# %%
I2 = np.abs(iI) * 100
I2.max()
# Out:
# 62.188232069067986

# %%
res = np.zeros((50, 100), dtype=np.complex128)
for u in range(50):
    for v in range(100):
        res[u,v] = dft2_2(I2, v, u)

show(np.log(np.abs(res) + 1))

plt.plot(np.log(np.abs(res) + 1)[0, :], 'ro')
plt.show()

# %%
iI = np.fft.ifft2(res)

show(np.abs(iI))

# %%
I = np.ones((100,100))
# I[50:, :] = 2

u, v = 99, 99

N, M = I.shape
x = np.arange(0, M, 1)
y = np.arange(0, N, 1).reshape((N, 1))
power = -2 * np.pi * (u*x/M + v*y/N)

Re = I * np.cos(power)
Im = I * np.sin(power)

plt.figure(figsize=(10,5))
plt.imshow(np.c_[Re, Im], cmap='bwr')
plt.show()

# %%
I = np.ones((100,100))
# I[50:, :] = 2

u, v = 1, 1

N, M = I.shape
x = np.arange(0, M, 1)
y = np.arange(0, N, 1).reshape((N, 1))
power = -2 * np.pi * (u*x/M + v*y/N)

Re = I * np.cos(power)
Im = I * np.sin(power)

plt.figure(figsize=(10,5))
plt.imshow(np.c_[Re, Im], cmap='bwr')
plt.show()

# %%
I1 = cv.imread('pic/fft_vbar100x100.png', 0)
I2 = cv.imread('pic/fft_vbar_no_frame100x100.png', 0)
I3 = cv.imread('pic/fft_vbar_white_bar100x100.png', 0)
I4 = cv.imread('pic/fft_hbar100x100.png', 0)
I5 = cv.imread('pic/fft_scatter100x100.png', 0)

plt.figure(figsize=(15, 3))
plt.imshow(np.c_[I1, I2, I3, I4, I5], cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# I1f = np.fft.fftshift(np.fft.fft2(I1))
I1  = np.ones((100, 200))
I1[:, :100] = 0

I1f = np.fft.fft2(I1)
I1fm = np.log(np.abs(I1f) + 1)

show(I1fm)

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

z = I1fm
h, w = z.shape

x,y = np.mgrid[0:h:1, 0:w:1]

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(x, y, z, rstride=1, cstride=1, cmap='jet',alpha = 0.8)

plt.show()

# %%
show(I2)

# %%
I2f = np.fft.fftshift(np.fft.fft2(I2))
# I2f = np.fft.fft2(I2)
I2fm = np.log(np.abs(I2f) + 1)

show(I2fm)

# %%
I3f = np.fft.fftshift(np.fft.fft2(I3))
I3fm = np.log(np.abs(I3f) + 1)

show(I3fm)

# %%
t = np.round(I3fm)
len(t[t>0])
# Out:
# 100

# %%
I3f = np.fft.fftshift(np.fft.fft2(I3))
I3fm = np.log(np.abs(I3f) + 1)

show(I3fm)

# %%
w = np.arange(1e-5, 10, 0.1)
a = 1.0
Fw1 = 2 * np.sin(w) / w
Fw2 = 2 * np.sin(2 * w) / w
Fw5 = 2 * np.sin(5 * w) / w

plt.plot(w, Fw1, 'b', w, Fw2, 'g', w, Fw5, 'r')
plt.show()

# %%
x = np.linspace(0, 2*np.pi, 2000)
m = np.cos(x)+np.cos(10*x)+np.cos(100*x)+np.cos(200*x)+np.cos(500*x)+np.cos(1000*x);

plt.plot(x, m)
plt.show()

# %%
res = np.fft.fft(m)

# %%
plt.plot(np.abs(res))
plt.show()

# %%
n = 2000
x = np.linspace(0, 2*np.pi, n)
m = np.sqrt(x) + np.cos(x)+np.cos(10*x)+np.cos(100*x)+np.cos(200*x)+np.cos(800*x);
# m =  x**2 + np.cos(10 * x)
# x = 2 * np.pi

res = np.fft.fft(m)
plt.plot(x, np.abs(res), 'ro')
plt.show()

# %%
n = 2000
x = np.linspace(0, 2*np.pi, n)
x[:1000] = 0.0
x[1000:] = 1.0
m = x

res = np.fft.fft(m)
plt.plot(x, np.abs(res), "ro")
# plt.ylim([0, 100])
plt.show()

# %%
x = np.ones(100)
x[::2] = 0

# n = 1000
# m = np.cos(x)+np.cos(10*x)+np.cos(100*x)+np.cos(200*x)+np.cos(800*x);

# x = 2 * np.pi

res = np.fft.fft(x)
plt.plot(x, np.abs(res), 'ro')
plt.ylim([0, 1])
plt.show()
